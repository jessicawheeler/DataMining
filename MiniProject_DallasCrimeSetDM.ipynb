# %% [markdown]
# # Analysis of the Dallas Crime Dataset
# #### By Jean Jecha, Sharon Teo, Jessica Wheeler
#
# --------------------------------------------------------------------------

# %% [markdown]
# ## Introduction

# %% [markdown]
#    The goal of this Project is to __

# %% [markdown]
# ## The Dataset

# %% [markdown]
# We chose the Dallas Crime dataset, available at https://www.dallasopendata.com/Public-Safety/Police-Incidents/tbnj-w5hb.  The site also has metadata about the dataset as well as descriptions for each of the attributes.  The Dallas Crime dataset has a sufficient number of rows- 196k, and a large amount of columns - 102.  This would enable us to choose the most interesting attributes to focus our analysis on.  Some of the attributes in this dataset include Type of Incident, Year, Month, Day, and Time of the beginning of the occurrence as well as the end of occurrence, watch, location- latitude and logitude as well as neighborhood and division, call (911) problem, and whether the incident was classified as a gang or drug related offense. Analyzing these attributes will give us a lot of insight to the dataset and ultimately as to how safe the city of Dallas is.  More importantly, crime data analysis would give insight to the Dallas Police Department as to where and when to focus their resources.
#
#    Our dataset contained crimes going back to 2003 but were not recoded until between 2014 and 2017.  For example, a crime might have occurred in 2003 but not discovered until 2016, such as fraud, embezzlement, forgery, and counterfeit.  In looking at the dataset, most of the more complete information recorded started in 2015-2017.  Thus, for our analysis, we used data that only ocurred in 2016, using the attribute Year1ofOccurrence.

# %% [markdown]
# ## Our Analysis
#
# #### Overview

# %%
# Load Dallas Crime Dataset
# Orginal dataset from https://www.dallasopendata.com/Public-Safety/Police-Incidents/tbnj-w5hb

import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# read in the csv file
df = pd.read_csv('/Users/JessicaSibal/Downloads/Police_Incidents.csv')
df.head()
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   ﻿Incident Number w/ Year  Year of Incident  Incident Number wo/ Year  \
# 0              000003-2017              2017                         3
# 1              000003-2017              2017                         3
# 2              000003-2017              2017                         3
# 3              000004-2016              2016                         4
# 4              000004-2017              2017                         4
#
#   Offense Service Number Service Number ID Watch  \
# 0                000003E    000003-2017-01     3
# 1                000003E    000003-2017-02     3
# 2                000003E    000003-2017-03     3
# 3                000004D    000004-2016-01     3
# 4                000004E    000004-2017-01     3
#
#              Call (911) Problem                            Type of Incident  \
# 0           07 - MINOR ACCIDENT                     UCR - ASSAULT (AGG) M/V
# 1           07 - MINOR ACCIDENT                     UCR - ASSAULT (AGG) M/V
# 2           07 - MINOR ACCIDENT                     UCR - ASSAULT (AGG) M/V
# 3                    09V - UUMV  UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE
# 4  6XEA - DISTURBANCE EMERG AMB                 ASSAULT -BODILY INJURY ONLY
#
#   Penalty Class                    Type of Location           ...            \
# 0           NaN          Highway, Street, Alley ETC           ...
# 1           NaN          Highway, Street, Alley ETC           ...
# 2           NaN          Highway, Street, Alley ETC           ...
# 3            FS          Highway, Street, Alley ETC           ...
# 4            MA  Single Family Residence - Occupied           ...
#
#             UCR Offense Name      UCR Offense Description Offense Type  \
# 0  VANDALISM & CRIM MISCHIEF  CRIMINAL MISCHIEF/VANDALISM        PART2
# 1  VANDALISM & CRIM MISCHIEF  CRIMINAL MISCHIEF/VANDALISM        PART2
# 2  VANDALISM & CRIM MISCHIEF  CRIMINAL MISCHIEF/VANDALISM        PART2
# 3                       UUMV            AUTO THEFT - UUMV        PART1
# 4                    ASSAULT                      ASSAULT        Part2
#
#                                  Modus Operandi (MO) Family Offense  \
# 0  A/P INTENTIONALLY STRUCK COMP'S VEHICLE WITH H...             No
# 1  A/P INTENTIONALLY STRUCK COMP'S VEHICLE WITH H...             No
# 2  A/P INTENTIONALLY STRUCK COMP'S VEHICLE WITH H...             No
# 3                                               UUMV             No
# 4  SUSPECT ASSAULT COMPLAINANT WITH HANDS CAUSING...             No
#
#   Hate Crime  Gang Related Offense Victim Package Drug Related Incident  \
# 0        NaN                   UNK            NaN                   UNK
# 1        NaN                   UNK            NaN                   UNK
# 2        NaN                   UNK            NaN                   UNK
# 3        NaN                    No            NaN                    No
# 4        NaN                    No            NaN                    No
#
#               Update Date
# 0  01/09/2017 02:10:32 PM
# 1  01/09/2017 02:10:32 PM
# 2  01/09/2017 02:10:32 PM
# 3  04/20/2016 09:00:30 AM
# 4  01/05/2017 12:58:48 PM
#
# [5 rows x 102 columns]

# %%
#Removing spaces from headers to clean them up
#http://stackoverflow.com/questions/11346283/renaming-columns-in-pandas

df.columns = [x.strip().replace(' ', '') for x in df.columns]
df.columns = [x.strip().replace('/', '') for x in df.columns]
df.columns = [x.strip().replace('(', '') for x in df.columns]
df.columns = [x.strip().replace(')', '') for x in df.columns]
df.columns = [x.strip().replace('-', '') for x in df.columns]

# %%
#Now Let's take a look at our cleaned headers - beautiful!
df.head()
# Out:
#   ﻿IncidentNumberwYear  YearofIncident  IncidentNumberwoYear  \
# 0          000003-2017            2017                     3
# 1          000003-2017            2017                     3
# 2          000003-2017            2017                     3
# 3          000004-2016            2016                     4
# 4          000004-2017            2017                     4
#
#   OffenseServiceNumber ServiceNumberID Watch                Call911Problem  \
# 0              000003E  000003-2017-01     3           07 - MINOR ACCIDENT
# 1              000003E  000003-2017-02     3           07 - MINOR ACCIDENT
# 2              000003E  000003-2017-03     3           07 - MINOR ACCIDENT
# 3              000004D  000004-2016-01     3                    09V - UUMV
# 4              000004E  000004-2017-01     3  6XEA - DISTURBANCE EMERG AMB
#
#                                TypeofIncident PenaltyClass  \
# 0                     UCR - ASSAULT (AGG) M/V          NaN
# 1                     UCR - ASSAULT (AGG) M/V          NaN
# 2                     UCR - ASSAULT (AGG) M/V          NaN
# 3  UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE           FS
# 4                 ASSAULT -BODILY INJURY ONLY           MA
#
#                        TypeofLocation           ...            \
# 0          Highway, Street, Alley ETC           ...
# 1          Highway, Street, Alley ETC           ...
# 2          Highway, Street, Alley ETC           ...
# 3          Highway, Street, Alley ETC           ...
# 4  Single Family Residence - Occupied           ...
#
#               UCROffenseName        UCROffenseDescription OffenseType  \
# 0  VANDALISM & CRIM MISCHIEF  CRIMINAL MISCHIEF/VANDALISM       PART2
# 1  VANDALISM & CRIM MISCHIEF  CRIMINAL MISCHIEF/VANDALISM       PART2
# 2  VANDALISM & CRIM MISCHIEF  CRIMINAL MISCHIEF/VANDALISM       PART2
# 3                       UUMV            AUTO THEFT - UUMV       PART1
# 4                    ASSAULT                      ASSAULT       Part2
#
#                                      ModusOperandiMO FamilyOffense HateCrime  \
# 0  A/P INTENTIONALLY STRUCK COMP'S VEHICLE WITH H...            No       NaN
# 1  A/P INTENTIONALLY STRUCK COMP'S VEHICLE WITH H...            No       NaN
# 2  A/P INTENTIONALLY STRUCK COMP'S VEHICLE WITH H...            No       NaN
# 3                                               UUMV            No       NaN
# 4  SUSPECT ASSAULT COMPLAINANT WITH HANDS CAUSING...            No       NaN
#
#    GangRelatedOffense VictimPackage DrugRelatedIncident  \
# 0                 UNK           NaN                 UNK
# 1                 UNK           NaN                 UNK
# 2                 UNK           NaN                 UNK
# 3                  No           NaN                  No
# 4                  No           NaN                  No
#
#                UpdateDate
# 0  01/09/2017 02:10:32 PM
# 1  01/09/2017 02:10:32 PM
# 2  01/09/2017 02:10:32 PM
# 3  04/20/2016 09:00:30 AM
# 4  01/05/2017 12:58:48 PM
#
# [5 rows x 102 columns]

# %%
# Narrowing down our focus to the attributes mentioned in the Dataset 
# description by removing columns not used in analysis

for col in ['OffenseServiceNumber','ServiceNumberID','ReportingArea','Beat','Sector','CouncilDistrict',
            'DPDSwornMarshallsinvolved','ComplainantHomeAddress','ComplainantApartment','ComplainantZipCode',
            'ComplainantCity','ComplainantState','ComplainantBusinessName','ComplainantBusinessAddress',
            'YearAssignment','Weather','RespondingOfficer#1BadgeNo','RespondingOfficer#1Name','RespondingOfficer#2BadgeNo',
            'RespondingOfficer#2Name','ReportingOfficerBadgeNo','AssistingOfficerBadgeNo','ReviewingOfficerBadgeNo',
            'ElementNumberAssigned','InvestigatingUnit1','InvestigatingUnit2','SpecialReportPreRMS','UCRDisposition',
            'UCR1','UCR2PreRMS','FinalUCR','RMSCode','CJISCode','PenalCode','HateCrime','VictimPackage']:
    if col in df:
        del df[col]

# %%
# We want to clean up the time attributes and turn them from objects to time.
# Reference: http://stackoverflow.com/questions/16852911/how-do-i-convert-dates-in-a-pandas-data-frame-to-a-date-data-type
df['StartingDateTime'] = pd.to_datetime(df['StartingDateTime'])
df['EndingDateTime'] = pd.to_datetime(df['EndingDateTime'])

# %%
#Subset the dataset to years 2016 present
# Reference: http://stackoverflow.com/questions/18172851/deleting-dataframe-row-in-pandas-based-on-column-value

df = df[df.Year1ofOccurrence == 2016]

# %%
#Let's get the specs of our subsetted data:
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99178 entries, 0 to 195573
# Data columns (total 66 columns):
# ﻿IncidentNumberwYear          99178 non-null object
# YearofIncident                99178 non-null int64
# IncidentNumberwoYear          99178 non-null int64
# Watch                         99178 non-null object
# Call911Problem                99165 non-null object
# TypeofIncident                99178 non-null object
# PenaltyClass                  84455 non-null object
# TypeofLocation                99067 non-null object
# TypeofProperty                27047 non-null object
# StreetBlock                   97388 non-null float64
# StreetDirection               3087 non-null object
# StreetName                    97566 non-null object
# IncidentAddress               98835 non-null object
# ApartmentNumber               17565 non-null object
# ZipCode                       98817 non-null float64
# City                          98835 non-null object
# State                         98749 non-null object
# XCoordinate                   97236 non-null float64
# YCoordinate                   97236 non-null float64
# Division                      99158 non-null object
# TargetAreaActionGrids         51465 non-null object
# Community                     9735 non-null object
# Date1ofOccurrence             99178 non-null object
# Year1ofOccurrence             99178 non-null float64
# Month1ofOccurence             99178 non-null object
# Day1oftheWeek                 99178 non-null object
# Time1ofOccurrence             99178 non-null object
# Day1oftheYear                 99178 non-null float64
# Date2ofOccurrence             99178 non-null object
# Year2ofOccurrence             99178 non-null float64
# Month2ofOccurence             99178 non-null object
# Day2oftheWeek                 99178 non-null object
# Time2ofOccurrence             99178 non-null object
# Day2oftheYear                 99178 non-null float64
# StartingDateTime              99178 non-null datetime64[ns]
# EndingDateTime                99178 non-null datetime64[ns]
# MapDate                       0 non-null float64
# DateofReport                  99178 non-null object
# Dateincidentcreated           99178 non-null object
# OffenseEnteredYear            99178 non-null int64
# OffenseEnteredMonth           99178 non-null object
# OffenseEnteredDayoftheWeek    99178 non-null object
# OffenseEnteredTime            99178 non-null object
# OffenseEnteredDateTime        99178 non-null int64
# CallReceivedDateTime          99165 non-null object
# CallDateTime                  99165 non-null object
# CallClearedDateTime           99147 non-null object
# CallDispatchDateTime          99156 non-null object
# PersonInvolvementType         99112 non-null object
# ComplainantName               87032 non-null object
# ComplainantRace               63397 non-null object
# ComplainantGender             63397 non-null object
# ComplainantAge                63032 non-null float64
# ComplainantAgeatOffense       63032 non-null float64
# OffenseStatus                 98935 non-null object
# VictimInjuryDescription       5846 non-null object
# VictimCondition               4830 non-null object
# OffenseCodeCC                 99178 non-null object
# UCROffenseName                99178 non-null object
# UCROffenseDescription         99178 non-null object
# OffenseType                   99178 non-null object
# ModusOperandiMO               99109 non-null object
# FamilyOffense                 99176 non-null object
# GangRelatedOffense            99176 non-null object
# DrugRelatedIncident           99176 non-null object
# UpdateDate                    99178 non-null object
# dtypes: datetime64[ns](2), float64(11), int64(4), object(49)
# memory usage: 50.7+ MB
# None

# %% [markdown]
# # Conclusion
