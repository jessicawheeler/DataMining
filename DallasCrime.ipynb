# %%
#Data from this website: https://www.dallasopendata.com/Public-Safety/Police-Incidents/tbnj-w5hb

import pandas as pd
import numpy as np

df = pd.read_json('https://www.dallasopendata.com/resource/qqc2-eivj.json')

df.head()
# Out:
#                   address aptnum assoffbadge  beat      blk  \
# 0      100 W CLARENDON DR    NaN        7397   446    100.0
# 1    3217 CHAPEL CREEK DR    NaN        7098   536   3217.0
# 2     2641 S LANCASTER RD    NaN       10474   722   2641.0
# 3  11611 HARRY HINES BLVD    NaN        7671   551  11611.0
# 4   5555 SPRING VALLEY RD   1034        5899   632   5555.0
#
#                callcleared           calldispatched              callorgdate  \
# 0  2015-03-14T02:38:58.000  2015-03-14T00:52:34.000  2015-03-14T00:36:38.000
# 1  2016-01-20T19:58:27.000  2016-01-20T15:50:03.000  2016-01-20T15:16:36.000
# 2  2016-02-15T22:13:09.000  2016-02-15T20:23:09.000  2016-02-15T20:16:17.000
# 3  2016-03-25T23:21:40.000  2016-03-25T21:52:42.000  2016-03-25T21:26:47.000
# 4  2016-03-25T23:45:59.000  2016-03-25T22:42:34.000  2016-03-25T22:32:19.000
#
#               callreceived    city   ...     ucr1              ucroffdesc  \
# ...

# %%
df.describe()
# Out:
# C:\Users\WheeleJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#               beat           blk          cjis     compage  \
# count  1000.000000    987.000000  1.000000e+03  611.000000
# mean    421.702000   5212.423506  4.423595e+07   39.975450
# std     193.997036   4002.526787  3.299201e+07   14.909048
# min     112.000000    100.000000  9.990026e+06   17.000000
# 25%     245.000000           NaN  2.299000e+07         NaN
# 50%     425.000000           NaN  2.411000e+07         NaN
# 75%     552.000000           NaN  5.499001e+07         NaN
# max     757.000000  38801.000000  1.000000e+08   85.000000
#
#        compageatoffensetime  comphzipcode  date1dayofyear  date2dayofyear  \
# count            611.000000     823.00000     1000.000000     1000.000000
# mean              39.913257   74820.26610      128.232000      125.572000
# ...

# %%
print (df.dtypes)
print (df.info())
# Out:
# address                  object
# aptnum                   object
# assoffbadge              object
# beat                      int64
# blk                     float64
# callcleared              object
# calldispatched           object
# callorgdate              object
# callreceived             object
# city                     object
# cjis                      int64
# community                object
# compage                 float64
# compageatoffensetime    float64
# compbaddress             object
# compbusname              object
# compcity                 object
# comphaddress             object
# comphapt                 object
# comphzipcode            float64
# compname                 object
# comprace                 object
# compsex                  object
# compstate                object
# date1                    object
# date1dayofyear            int64
# date2                    object
# date2dayofyear            int64
# day1                     object
# ...

# %%
dallas_crime = df['watch', 'signal', 'offincident', 'premise', 'objattack']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-7fda12a6c41e> in <module>()
# ----> 1 dallas_crime = df['watch', 'signal', 'offincident', 'premise', 'objattack']
#
# C:\Users\WheeleJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Users\WheeleJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
df['watch', 'signal', 'offincident', 'premise', 'objattack']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-ebf65260e880> in <module>()
# ----> 1 df['watch', 'signal', 'offincident', 'premise', 'objattack']
#
# C:\Users\WheeleJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Users\WheeleJ\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...
